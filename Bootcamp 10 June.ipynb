# %%
def longest_increasing_subsequence(nums):
    if not nums:
        return []
    
    n = len(nums)
    dp = [1] * n
    predecessor = [-1] * n
    
    for i in range(1, n):
        for j in range(i):
            if nums[i] > nums[j] and dp[i] < dp[j] + 1:
                dp[i] = dp[j] + 1
                predecessor[i] = j
    
    max_length = max(dp)
    index = dp.index(max_length)
    
    lis = []
    while index != -1:
        lis.append(nums[index])
        index = predecessor[index]
    
    return lis[::-1]


nums = [10, 9, 2, 5, 3, 7, 101, 18]
print(longest_increasing_subsequence(nums))

# %%
def next_permutation(nums):
    n = len(nums)
    i = n - 2

    while i >= 0 and nums[i] >= nums[i + 1]:
        i -= 1

    if i >= 0:
        j = n - 1
        while nums[j] <= nums[i]:
            j -= 1
        nums[i], nums[j] = nums[j], nums[i]

    nums[i + 1:] = reversed(nums[i + 1:])


nums = [1, 2, 3]
next_permutation(nums)
print(nums)

# %%
def trap(height):
    if not height:
        return 0

    n = len(height)
    left, right = 0, n - 1
    left_max, right_max = height[left], height[right]
    water_trapped = 0

    while left < right:
        if left_max < right_max:
            left += 1
            left_max = max(left_max, height[left])
            water_trapped += max(0, left_max - height[left])
        else:
            right -= 1
            right_max = max(right_max, height[right])
            water_trapped += max(0, right_max - height[right])

    return water_trapped

height = [0,1,0,2,1,0,1,3,2,1,2,1]
print(trap(height))

# %%
from collections import Counter

def find_anagrams(s, p):
    p_count = Counter(p)
    s_count = Counter(s[:len(p) - 1])
    result = []
    
    for i in range(len(p) - 1, len(s)):
        s_count[s[i]] += 1
        if s_count == p_count:
            result.append(i - len(p) + 1)
        s_count[s[i - len(p) + 1]] -= 1
        if s_count[s[i - len(p) + 1]] == 0:
            del s_count[s[i - len(p) + 1]]
    
    return result


s = "cbaebabacd"
p = "abc"
print(find_anagrams(s, p))

# %%
def count_smaller(nums):
    result = []
    sorted_list = []
    
    for num in reversed(nums):
        left, right = 0, len(sorted_list)
        
        while left < right:
            mid = (left + right) // 2
            if sorted_list[mid] < num:
                left = mid + 1
            else:
                right = mid
        
        result.append(left)
        sorted_list.insert(left, num)
    
    return result[::-1]


nums = [5, 2, 6, 1]
print(count_smaller(nums))

# %%
def longest_increasing_subsequence(nums):
    if not nums:
        return ()

    n = len(nums)
    dp = [1] * n
    predecessor = [-1] * n

    for i in range(1, n):
        for j in range(i):
            if nums[i] > nums[j] and dp[i] < dp[j] + 1:
                dp[i] = dp[j] + 1
                predecessor[i] = j

    max_length = max(dp)
    index = dp.index(max_length)

    lis = ()
    while index != -1:
        lis += (nums[index],)
        index = predecessor[index]

    return lis[::-1]

nums = (10, 9, 2, 5, 3, 7, 101, 18)
print(longest_increasing_subsequence(nums))

# %%
def next_permutation(nums):
    nums = list(nums)
    n = len(nums)
    i = n - 2

    while i >= 0 and nums[i] >= nums[i + 1]:
        i -= 1

    if i >= 0:
        j = n - 1
        while nums[j] <= nums[i]:
            j -= 1
        nums[i], nums[j] = nums[j], nums[i]

    nums[i + 1:] = reversed(nums[i + 1:])
    return tuple(nums)


nums = (1, 2, 3)
print(next_permutation(nums))

# %%
def trap(height):
    if not height:
        return 0

    n = len(height)
    left, right = 0, n - 1
    left_max, right_max = height[left], height[right]
    water_trapped = 0

    while left < right:
        if left_max < right_max:
            left += 1
            left_max = max(left_max, height[left])
            water_trapped += max(0, left_max - height[left])
        else:
            right -= 1
            right_max = max(right_max, height[right])
            water_trapped += max(0, right_max - height[right])

    return water_trapped

height = (0,1,0,2,1,0,1,3,2,1,2,1)
print(trap(height))

# %%
from collections import Counter

def find_anagrams(s, p):
    p_count = Counter(p)
    s_count = Counter(s[:len(p) - 1])
    result = []

    for i in range(len(p) - 1, len(s)):
        s_count[s[i]] += 1
        if s_count == p_count:
            result.append(i - len(p) + 1)
        s_count[s[i - len(p) + 1]] -= 1
        if s_count[s[i - len(p) + 1]] == 0:
            del s_count[s[i - len(p) + 1]]

    return tuple(result)


s = "cbaebabacd"
p = "abc"
print(find_anagrams(s, p))

# %%
def next_permutation(nums):
    nums = list(nums)
    n = len(nums)
    i = n - 2

    while i >= 0 and nums[i] >= nums[i + 1]:
        i -= 1

    if i >= 0:
        j = n - 1
        while nums[j] <= nums[i]:
            j -= 1
        nums[i], nums[j] = nums[j], nums[i]

    nums[i + 1:] = reversed(nums[i + 1:])
    return tuple(nums)


nums = (1, 2, 3)
print(next_permutation(nums))

# %%
def count_smaller(nums):
    result = []
    sorted_list = []

    for num in reversed(nums):
        left, right = 0, len(sorted_list)

        while left < right:
            mid = (left + right) // 2
            if sorted_list[mid] < num:
                left = mid + 1
            else:
                right = mid

        result.append(left)
        sorted_list.insert(left, num)

    return tuple(result[::-1])

nums = (5, 2, 6, 1)
print(count_smaller(nums))

# %%
def common_elements_set(set1, set2):
    return set1.intersection(set2)


set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
print(common_elements_set(set1, set2))

# %%
def max_element_list(nums):
    return max(nums)


nums_list = [1, 7, 3, 9, 5]
print(max_element_list(nums_list))

# %%
def count_unique_elements_tuple(tup):
    return len(set(tup))


tup = (1, 2, 3, 2, 4, 5, 3)
print(count_unique_elements_tuple(tup))

# %%
def find_duplicate_characters_string(s):
    duplicates = set()
    seen = set()

    for char in s:
        if char in seen:
            duplicates.add(char)
        else:
            seen.add(char)

    return duplicates

string = "hello"
print(find_duplicate_characters_string(string))

# %%
def sort_dict_by_values(d):
    return {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}


my_dict = {'a': 3, 'b': 1, 'c': 2}
print(sort_dict_by_values(my_dict))

# %%
def merge_two_dicts(dict1, dict2):
    merged_dict = dict1.copy()
    merged_dict.update(dict2)
    return merged_dict


dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
print(merge_two_dicts(dict1, dict2))

# %%
def max_value_key(dictionary):
    return max(dictionary, key=dictionary.get)

my_dict = {'a': 10, 'b': 5, 'c': 20}
print(max_value_key(my_dict))

# %%
def char_frequency(string):
    frequency = {}
    for char in string:
        frequency[char] = frequency.get(char, 0) + 1
    return frequency

string = "hello"
print(char_frequency(string))

# %%
def dicts_are_equal(dict1, dict2):
    return dict1 == dict2

dict1 = {'a': 1, 'b': 2}
dict2 = {'a': 1, 'b': 2}
print(dicts_are_equal(dict1, dict2))

# %%
def total_dict_values(dictionary):
    return sum(dictionary.values())

my_dict = {'a': 10, 'b': 5, 'c': 20}
print(total_dict_values(my_dict))
